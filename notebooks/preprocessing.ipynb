# %% [markdown]
# # Pre-Processing Data

# %%
import sys
import os

PROJECT_ROOT = os.path.abspath("..")
sys.path.append(PROJECT_ROOT)

# %%
from src.data_loader import load_data
from src.preprocessing import *
from src.feature_engineering import *

data = load_data("../DataSets/merged_movies_ratings.csv")

data = handle_missing_year(data)
data = remove_duplicates(data)

data = filter_sparse_users(data)
data = filter_sparse_movies(data)

data = rating_normalization(data)

data.head()
# Out:
#    userId  movieId  rating   timestamp  \
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580
#
#                                                title  \
# 0                                            Jumanji
# 1  City of Lost Children, The (Cité des enfants p...
# 2                 Twelve Monkeys (a.k.a. 12 Monkeys)
# 3                               Seven (a.k.a. Se7en)
# 4                                Usual Suspects, The
#
#                                    genres    year  \
# 0              Adventure|Children|Fantasy  1995.0
# 1  Adventure|Drama|Fantasy|Mystery|Sci-Fi  1995.0
# 2                 Mystery|Sci-Fi|Thriller  1995.0
# 3                        Mystery|Thriller  1995.0
# 4                  Crime|Mystery|Thriller  1995.0
#
#                                           genre_list  rating_normalized
# ...

# %%
print("Rows:", len(data))
print("Unique users:", data['userId'].nunique())
print("Unique movies:", data['movieId'].nunique())
# Out:
# Rows: 15487807
# Unique users: 52596
# Unique movies: 6536

# %%
# from src.user_matrix_builder import *

# matrix = create_user_movie_matrix(data)

# save_user_movie_matrix(matrix,"../data/processed/user_movie_matrix.pkl")
